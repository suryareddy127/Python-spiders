# %%
a=7
b=3+4j

print(a+b) #add
print(a-b) #sub
print(a*b) # mul
print(a/b) #div 
print(a//b)# remainder off      TypeError: unsupported operand type(s) for //: 'int' and 'complex'
print(a**b) #exponent
print(type(a*b))
# Out:
# (10+4j)
# (4-4j)
# (21+28j)
# (0.84-1.12j)
# (24.107084714676866+342.15179155830737j)
# <class 'complex'>

# %%
a=7
b=3

print(a<b)  #less than
print(a>b) #greater than
print(a==b) #equalto
print(a<=b) #less than equalto
print(a>=b) #greater than equalto
print(a!=b) #not equalto
# Out:
# False
# True
# False
# False
# True
# True
